# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('Downloads/NBA_data (1).csv')

# %%
data
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    497 non-null    object
#  1   Position                  497 non-null    object
#  2   Age                       497 non-null    int64
#  3   Games                     497 non-null    int64
#  4   Minutes Played            495 non-null    float64
#  5   True Shooting(%)          494 non-null    float64
#  6   Threepoint Attempt rate   495 non-null    float64
#  7   Free throw attempt rate   495 non-null    float64
#  8   Player Efficiency Rating  497 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 35.1+ KB

# %%
data.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["Player"]=abc.fit_transform(data["Player"])

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["Position"]=abc.fit_transform(data["Position"])

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["Minutes Played"]=abc.fit_transform(data["Minutes Played"])

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["True Shooting(%)"]=abc.fit_transform(data["True Shooting(%)"])

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["Free throw attempt rate"]=abc.fit_transform(data["Free throw attempt rate"])

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["Player Efficiency Rating"]=abc.fit_transform(data["Player Efficiency Rating"])

# %%
from sklearn.preprocessing import LabelEncoder
abc=LabelEncoder()

data["Threepoint Attempt rate"]=abc.fit_transform(data["Threepoint Attempt rate"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    497 non-null    int32
#  1   Position                  497 non-null    int32
#  2   Age                       497 non-null    int64
#  3   Games                     497 non-null    int64
#  4   Minutes Played            497 non-null    int64
#  5   True Shooting(%)          497 non-null    int64
#  6   Threepoint Attempt rate   497 non-null    int64
#  7   Free throw attempt rate   497 non-null    int64
#  8   Player Efficiency Rating  497 non-null    int64
# dtypes: int32(2), int64(7)
# memory usage: 31.2 KB

# %%
import matplotlib as plt
print(plt.get_cachedir())
# Out:
# C:\Users\yagan\.matplotlib

# %%
data.describe()
# Out:
#            Player    Position         Age       Games  Minutes Played  \
# count  497.000000  497.000000  497.000000  497.000000      497.000000
# mean   240.060362    4.770624   25.623742   18.456740      180.018109
# std    139.577590    2.672987    4.054229    8.311394      115.060966
# min      0.000000    0.000000   19.000000    1.000000        0.000000
# 25%    118.000000    4.000000   22.000000   12.000000       73.000000
# 50%    238.000000    5.000000   25.000000   20.000000      181.000000
# 75%    362.000000    6.000000   28.000000   26.000000      280.000000
# max    480.000000    8.000000   37.000000   30.000000      383.000000
#
#        True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# count        497.000000               497.000000               497.000000
# mean         131.965795               160.889336               124.921529
# std           65.649307                97.261732                81.472907
# ...

# %%
data.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              0
# True Shooting(%)            0
# Threepoint Attempt rate     0
# Free throw attempt rate     0
# Player Efficiency Rating    0
# dtype: int64

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
sns.barplot(data=data)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
topic = ["Threepoint Attempt rate","Free throw attempt rate","Player Efficiency Rating"]
Postive_percentage = ["160.889336","124.921529","108.859155"]


sizes = Postive_percentage
print(sizes)
labels = list(topic)
# makeitastring = ''.join(map(str, labels))
print(labels)
colors = ['yellow', 'lightgreen', 'blue', 'red',]
plt.pie(sizes, explode=None, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)   
#plt.pie(sizes, labels, colors)
plt.axis('equal')
plt.legend()
plt.show()
# Out:
# ['160.889336', '124.921529', '108.859155']
# ['Threepoint Attempt rate', 'Free throw attempt rate', 'Player Efficiency Rating']

# %%
sns.pairplot(data[['Player','Position','Age','Games','Minutes Played']])

# %%
x=data.drop(["Player Efficiency Rating"],axis=1)

y=data["Player Efficiency Rating"]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
teja=LinearRegression()
teja.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=teja.predict(x_test)

# %%
print("training accuracy:",teja.score(x_train,y_train))
print("testing accuracy:",teja.score(x_test,y_test))
# Out:
# training accuracy: 0.6584877092940588
# testing accuracy: 0.6471234751809427

# %%
y_test=list(y_test)

# %%
plt.figure(figsize=(20,20))
plt.plot(y_test,label="test",color="blue")
plt.plot(y_pred,label="pred",color="green")
plt.title("Player Efficiency Rating")
plt.legend()
plt.show()
